# %% [markdown]
# <a href="https://colab.research.google.com/github/crisfisico/minicurso-python/blob/main/Aula_03_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráficos em Python com `matplotlib`
#
# [matplotlib.org](https://matplotlib.org/stable/index.html)
#
# Outras bibliotecas:
#
# *   [seaborn](https://seaborn.pydata.org/)
# *   [plotly](https://plotly.com/python/)

# %% [markdown]
# # Carregando as bibliotecas

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
print('matplotlib:',mpl.__version__)
print('numpy:',np.__version__)
# Out:
# matplotlib: 3.2.2
# numpy: 1.19.5

# %% [markdown]
# ## Primeiro exemplo

# %%
plt.plot([1,2,3,4,5]) # y = [1,2,3,4]] e x = [0,1,2,3] (gerado automaticamente)
plt.show()

# %%
x = np.array([0,1,2,3,4])
y = np.array([0,1,4,9,16])
plt.plot(x,y,marker='o',linestyle=':',color='red',label="func quadratica")
plt.xlabel("eixo-x")
plt.ylabel("eixo-y")
plt.xlim(-1,5)
plt.ylim(-1,18)
plt.legend()
plt.show()
# saiba mais: Todas as opcoes para, por exemplo: marker,linestyle e color encontram-se tabeladas em:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
x = np.array([0,1,2,3,4])
y = np.array([0,1,4,9,16])
plt.plot(x,x,marker='o',linestyle=':',color='blue',label="func linear")
plt.plot(x,y,marker='^',linestyle=':',color='red',label="func quadratica")
plt.xlabel("eixo-x")
plt.ylabel("eixo-y")
plt.xlim(0,5)
plt.ylim(-1,18)
plt.legend()
plt.show()

# %% [markdown]
# ## Instrucoes para mudar as propriedades da figura

# %%
plt.rcdefaults()
# Alterando algumas configuracoes
plt.rc('figure',figsize=(8,6))
plt.rc('lines',linewidth=4,linestyle='--',markersize=14)
plt.rc('axes',linewidth=1.5,labelsize=16)
plt.rc('xtick',direction='in',labelsize=16)
plt.rc('ytick',direction='in',labelsize=16)
plt.rc('legend',frameon='False',fontsize=10,loc='best')

# a linha abaixo restaura a configuracao padrao
# plt.rcdefaults()
# a linha abaixo mostra a configuracao padrao
# plt.rcParamsDefault
# a linha abaixo mostra a configuracao atual
# plt.rcParams

# Saiba mais: 
#https://matplotlib.org/stable/tutorials/introductory/customizing.html#sphx-glr-tutorials-introductory-customizing-py
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.rc.html
#https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.rcParams

# %%
x = np.array([0,1,2,3,4])
y = np.array([0,1,4,9,16])
plt.plot(x,x,marker='o',linestyle=':',color='blue',label="func linear")
plt.plot(x,y,marker='^',linestyle=':',color='red',label="func quadratica")
plt.xlabel("eixo-x")
plt.ylabel("eixo-y")
plt.xlim(0,5)
plt.ylim(-1,18)
plt.legend()
plt.show()

# %% [markdown]
# Há também tipos pré-definidos de estilos que pode-se carregar facilmente

# %%
# Restaura o padrao
# plt.rcdefaults()

# Restaura o estilo padrao
# plt.style.use('default')

# Mostra os estilos disponiveis
#print(plt.style.available)

# Estilo escuro
plt.style.use(['dark_background'])

x = np.array([0,1,2,3,4])
y = np.array([0,1,4,9,16])
plt.plot(x,x,marker='o',linestyle=':',color='blue',label="func linear")
plt.plot(x,y,marker='^',linestyle=':',color='red',label="func quadratica")
plt.xlabel("eixo-x")
plt.ylabel("eixo-y")
plt.xlim(0,5)
plt.ylim(-1,18)
plt.legend()
plt.show()

# %% [markdown]
# ## Usando `subplots`

# %% [markdown]
# Há duas formas (pelo menos) de criar gráficos com o `matplotlib`, a segunda forma que veremos agora tem mais a cara de **programação orientada a objeto (OOP)**. É minha preferida :)

# %% [markdown]
# Usamos anteriormente `plt.plot` para gerarmos os gráficos, mas havia uma chamada implícita para gerar uma figura `plt.figure`, em geral não precisamos utiliza-la, exceto se vc quisesse, por exemplo, mudar o tamanho da figura, veja exemplo abaixo.

# %%
#fig = plt.figure() # Esta linha é gerada automaticamente, caso vc não a digite
fig = plt.figure(figsize=(6,6)) # Esta linha é gerada automaticamente, caso vc não a use.
plt.plot(x,x)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,x)
plt.show()

# %%
fig, ax = plt.subplots(1,2) # num de linhas por num de colunas
ax[0].plot(x,x)
ax[1].plot(x,x*x)
plt.show()

# %%
fig, axs = plt.subplots(2,3,figsize=(15,5)) # num de linhas = 2 por num de colunas = 3. pode ser qualquer combinação 
axs[0][0].plot(x,x**1)
axs[0][1].plot(x,x**2)
axs[0][2].plot(x,x**3)
axs[1][0].plot(x,x**4)
axs[1][1].plot(x,x**5)
axs[1][2].plot(x,x**6)
plt.show()

# %%
fig, axs = plt.subplots(2,3,figsize=(15,10)) # num de linhas por num de colunas

axs[0][0].plot(x,x**1)
axs[0][0].set_xlabel("eixo-x 00")
axs[0][0].set_ylabel("eixo-y 00")
axs[0][0].set_xlim(-3,3)
axs[0][0].set_ylim(-3,3)

axs[0][1].plot(x,x**2)
axs[0][2].plot(x,x**3)
axs[1][0].plot(x,x**4)
axs[1][1].plot(x,x**5)
axs[1][2].plot(x,x**6)
plt.show()

# %% [markdown]
# ## Funções trigonométricas

# %% [markdown]
# Abaixo, usamos o `plt.subplots` para plotar as principais funções trigonométricas. Também mostramos como utilizar font `latex` e label dos eixos customizados usando a função `set_xticklabels`

# %%
fig1, ax1 = plt.subplots(2,1,figsize=(12,8)) # num de linhas por num de colunas

theta = np.linspace(-np.pi,np.pi,100)
ax1[0].plot(theta,np.sin(theta),label=r'$sen(\theta)$')
ax1[0].plot(theta,np.cos(theta),label=r'$cos(\theta)$')
ax1[0].legend()

# Define quais os xticks quer q apareça
ax1[0].set_xticks((-np.pi, -np.pi/2, 0.0, np.pi/2, np.pi))
# Modifica o label dos xticks que serao mostrados
ax1[0].set_xticklabels((r'$-\pi$', r'$-\frac{\pi}{2}$', r'$0$', r'$\frac{\pi}{2}$', r'$\pi$'))

ax1[1].plot(theta,np.sin(theta),label=r'$cos(\theta)$')
ax1[1].plot(theta,np.cos(theta),label=r'$cos(\theta)$')
ax1[1].legend()

# Caso não quisesse mostrar os labels:
ax1[1].set_xticks([]) 

# Saiba mais:
# Funções trigonométricas: https://numpy.org/doc/stable/reference/routines.math.html
# Latex: https://matplotlib.org/stable/tutorials/text/mathtext.html
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticklabels.html
# Out:
# []

# %%
fig1, ax1 = plt.subplots(2,3,figsize=(14,8),sharex=True) # Observe o que sharex,sharey fazem :)

# Define quais os xticks quer q apareça
ax1[0][0].set_xticks((-2*np.pi,-1.5*np.pi,-np.pi, -np.pi/2, 0.0, np.pi/2, np.pi,1.5*np.pi,2*np.pi))
# Modifica o label dos xticks que serao mostrados
ax1[0][0].set_xticklabels((r'$-2\pi$',r'$-\frac{3\pi}{2}$',r'$-\pi$', r'$-\frac{\pi}{2}$', r'$0$', r'$\frac{\pi}{2}$', r'$\pi$',r'$\frac{3\pi}{2}$',r'$2\pi$'))

theta = np.linspace(-2*np.pi,2*np.pi,50)
ax1[0][0].plot(theta,np.sin(theta),marker='o',linestyle=':',label=r'$sen(\theta)$')
ax1[0][0].legend()
ax1[0][1].plot(theta,np.cos(theta),marker='o',linestyle=':',label=r'$cos(\theta)$')
ax1[0][1].legend()
ax1[0][2].plot(theta,np.tan(theta),marker='o',linestyle=':',label=r'$tan(\theta)$')
ax1[0][2].legend()
ax1[0][2].set_ylim(-10,10)

#ax1[1].plot(theta,1.0/np.sin(theta))
ax1[1][0].plot(theta,1.0/np.sin(theta),marker='o',linestyle=':',label=r'$cossec(\theta)$')
ax1[1][0].legend()
ax1[1][0].set_ylim(-10,10)
ax1[1][1].plot(theta,1.0/np.cos(theta),marker='o',linestyle=':',label=r'$sec(\theta)$')
ax1[1][1].legend()
ax1[1][1].set_ylim(-10,10)
ax1[1][2].plot(theta,1.0/np.tan(theta),marker='o',linestyle=':',label=r'$cotan(\theta)$')
ax1[1][2].legend()
ax1[1][2].set_ylim(-10,10)
#ax1[1][1].set_xlim(-np.pi,np.pi)
#ax1[1][1].set_ylim(-10,10)

# Caso não quisesse mostrar os labels:
#ax1[1].set_xticks([]) 
plt.show()

# Saiba mais:
# Funções trigonométricas: https://numpy.org/doc/stable/reference/routines.math.html
# Latex: https://matplotlib.org/stable/tutorials/text/mathtext.html
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticklabels.html
